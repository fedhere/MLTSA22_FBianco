# %% [markdown]
# <a href="https://colab.research.google.com/github/fedhere/MLTSA22_FBianco/blob/main/Lab2Disrtibutions/GeneratingStochasticTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pylab as pl
import numpy as np

# %%
pl.figure(figsize=(20,5))
N = 200
np.random.seed(100)
y = np.random.randn(N) * N
t = np.linspace(0, N, N, endpoint=False)
pl.plot(t, y, lw=2)
pl.xlabel("time")
pl.ylabel("y");

# %%
pl.figure(figsize=(20,5))
pl.plot(t, y * t, lw=2)
pl.xlabel("time")
pl.ylabel("y");
